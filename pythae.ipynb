# %% [markdown]
# #

# %% [markdown]
# # pythae synthetic data generation

# %%
pip install pythae
# Out:
# Requirement already satisfied: pythae in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (0.1.1)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (2.2.1)
# Requirement already satisfied: imageio in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (2.27.0)
# Requirement already satisfied: pydantic>=1.8.2 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.10.7)
# Requirement already satisfied: numpy>=1.19 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.24.2)
# Requirement already satisfied: torch>=1.10.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.2.2)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.10.1)
# Requirement already satisfied: dataclasses>=0.6 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (0.6)
# Requirement already satisfied: tqdm in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (4.5.0)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from imageio->pythae) (9.4.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->pythae) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->pythae) (3.1.0)
# Requirement already satisfied: colorama in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from tqdm->pythae) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pythae
# Out:
# Requirement already satisfied: pythae in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (0.1.1)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (2.2.1)
# Requirement already satisfied: typing-extensions in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (4.5.0)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.10.1)
# Requirement already satisfied: dataclasses>=0.6 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (0.6)
# Requirement already satisfied: numpy>=1.19 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.24.2)
# Requirement already satisfied: scikit-learn in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.2.2)
# Requirement already satisfied: tqdm in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (4.65.0)
# Requirement already satisfied: torch>=1.10.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.13.1)
# Requirement already satisfied: imageio in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (2.27.0)
# Requirement already satisfied: pydantic>=1.8.2 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from pythae) (1.10.7)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from imageio->pythae) (9.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->pythae) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->pythae) (1.2.0)
# Requirement already satisfied: colorama in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from tqdm->pythae) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## vaegan

# %% [markdown]
# # @article{chadebec2022pythae,
# 	title={Pythae: Unifying Generative Autoencoders in Python -- A Benchmarking Use Case},
#   	author={Chadebec, Clément and Vincent, Louis J. and Allassonnière, Stéphanie},
#   	journal={arXiv preprint arXiv:2206.08309},
# 	url = {https://arxiv.org/abs/2206.08309},
#   	year = {2022}
# }

# %%
import numpy as np
import pandas as pd
import sdv
import seaborn as sns
import matplotlib.pyplot as plt

#libraries needed for pythae
from pythae.models import VAEGAN, VAEGANConfig
from pythae.trainers import CoupledOptimizerAdversarialTrainerConfig
from pythae.pipelines.training import TrainingPipeline

#pytorch
import torch


device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
sdv.__version__
# Out:
# '1.0.0b1'

# %%
real_data1=pd.read_csv('german_credit_data.csv')

#data transforming to numerical values using sdv
from rdt import HyperTransformer
ht = HyperTransformer()

# do not transform any categorical columns in the dataset
ht.remove_transformers_by_sdtype(sdtype='numerical')
ht.detect_initial_config(data=real_data1)
config=ht.get_config()
ht.fit(real_data1)

real_data_t=ht.transform(real_data1)

#changing from pd to torch verison
real_data=torch.Tensor(real_data_t.values)

# %%
real_data1.shape
# Out:
# (1000, 21)

# %%
real_data
# Out:
# tensor([[ 0.5310,  6.0000,  0.6765,  ...,  0.7980,  0.4815,  0.3500],
#         [ 0.8025, 48.0000,  0.2650,  ...,  0.2980,  0.4815,  0.8500],
#         [ 0.1970, 12.0000,  0.6765,  ...,  0.2980,  0.4815,  0.3500],
#         ...,
#         [ 0.1970, 12.0000,  0.2650,  ...,  0.2980,  0.4815,  0.3500],
#         [ 0.5310, 45.0000,  0.2650,  ...,  0.7980,  0.4815,  0.8500],
#         [ 0.8025, 45.0000,  0.6765,  ...,  0.2980,  0.4815,  0.3500]])

# %%
#splitting datasets into train and test
from torch.utils.data import DataLoader, random_split


dataset = real_data
#splitting in 80:20 order
train_size = int(0.8 * len(dataset))  # 80% for train
test_size = len(dataset) - train_size  # remaining 20% for test

# Using random_split to randomly split the dataset
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# Creating data loaders for train and test datasets (optional)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
#VAEGAN model

#VAEGANConfig
model_config=VAEGANConfig(input_dim=( 1000, 21),
    latent_dim=16,
    adversarial_loss_scale=0.8,
    reconstruction_layer= 0,
    margin=0.4,
    equilibrium= 0.68
)

model = VAEGAN(
    model_config=model_config
)

#training_config
config = CoupledOptimizerAdversarialTrainerConfig(
    output_dir='my_model',
    learning_rate=1e-4,
    per_device_train_batch_size=200,
    per_device_eval_batch_size=200,
    num_epochs=10, # Change this to train the model a bit more
)

# %%
pipeline = TrainingPipeline(
    training_config=config,
    model=model
)

# %%
pipeline(
    train_data=train_dataset,
    eval_data=test_dataset
)
# Out:
# Checking train dataset...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pipeline(
#       2     train_data=train_dataset,
#       3     eval_data=test_dataset
#       4 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pythae\pipelines\training.py:181, in TrainingPipeline.__call__(self, train_data, eval_data, callbacks)
#     178     train_dataset = train_data
#     180 logger.info("Checking train dataset...")
# --> 181 self._check_dataset(train_dataset)
#     183 if eval_data is not None:
#     184     if isinstance(eval_data, np.ndarray) or isinstance(eval_data, torch.Tensor):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pythae\pipelines\training.py:125, in TrainingPipeline._check_dataset(self, dataset)
#     117 except Exception as e:
#     118     raise DatasetError(
#     119         "Error when trying to collect data from the dataset. Check `__getitem__` method. "
#     120         "The Dataset should output a dictionnary with keys at least ['data']. "
#     121         "Please check documentation.\n"
#     122         f"Exception raised: {type(e)} with message: " + str(e)
#     123     ) from e
# --> 125 if "data" not in dataset_output.keys():
#     126     raise DatasetError(
#     127         "The Dataset should output a dictionnary with keys ['data']"
#     128     )
#     130 try:
#
# AttributeError: 'Tensor' object has no attribute 'keys'

# %%
import os
from pythae.models import AutoModel
from pythae.samplers import NormalSampler

# %%
# create normal sampler
normal_samper = NormalSampler(
    model=model
)

# %%
gen_data = normal_samper.sample(
    num_samples=30000
)

# %%
gen_data
# Out:
# tensor([[[0.5554, 0.6214, 0.5679,  ..., 0.4331, 0.5897, 0.5300],
#          [0.4595, 0.4685, 0.4262,  ..., 0.5752, 0.5149, 0.3880],
#          [0.5027, 0.5122, 0.4196,  ..., 0.4170, 0.4895, 0.4722],
#          ...,
#          [0.5420, 0.5846, 0.4785,  ..., 0.5071, 0.5138, 0.4855],
#          [0.5788, 0.5166, 0.5338,  ..., 0.6035, 0.4866, 0.4619],
#          [0.4785, 0.5659, 0.4902,  ..., 0.5759, 0.3976, 0.5021]],
#
#         [[0.5098, 0.5176, 0.5007,  ..., 0.3846, 0.5380, 0.4235],
#          [0.4850, 0.3729, 0.3904,  ..., 0.4923, 0.4912, 0.5326],
#          [0.5450, 0.4638, 0.5035,  ..., 0.4814, 0.4457, 0.4599],
#          ...,
#          [0.5883, 0.5336, 0.5568,  ..., 0.5329, 0.4557, 0.4306],
#          [0.4763, 0.4674, 0.5315,  ..., 0.6503, 0.5274, 0.4057],
#          [0.4555, 0.4938, 0.4688,  ..., 0.5475, 0.5139, 0.4669]],
#
#         [[0.5409, 0.5184, 0.5576,  ..., 0.5153, 0.4430, 0.5600],
#          [0.4660, 0.4957, 0.4188,  ..., 0.5330, 0.5546, 0.4967],
#          [0.4014, 0.3932, 0.5047,  ..., 0.5396, 0.4969, 0.4640],
#          ...,
#          [0.5079, 0.5133, 0.4604,  ..., 0.4585, 0.3850, 0.4740],
#          [0.5897, 0.4939, 0.5770,  ..., 0.5598, 0.4883, 0.4256],
#          [0.4944, 0.4757, 0.5066,  ..., 0.4985, 0.5107, 0.4845]],
#
#         ...,
#
#         [[0.6444, 0.5548, 0.4803,  ..., 0.4552, 0.5495, 0.4972],
#          [0.5122, 0.3849, 0.4380,  ..., 0.4616, 0.5299, 0.5891],
#          [0.5195, 0.4718, 0.4638,  ..., 0.4898, 0.4884, 0.4957],
#          ...,
#          [0.5365, 0.6090, 0.5492,  ..., 0.4453, 0.5085, 0.3872],
#          [0.5522, 0.5477, 0.5303,  ..., 0.6370, 0.5266, 0.4509],
#          [0.4382, 0.5279, 0.4682,  ..., 0.6308, 0.4777, 0.4213]],
#
#         [[0.4807, 0.5277, 0.5682,  ..., 0.4309, 0.4396, 0.4646],
#          [0.4550, 0.5241, 0.4842,  ..., 0.4954, 0.5059, 0.4900],
#          [0.5025, 0.4733, 0.4667,  ..., 0.5903, 0.4390, 0.4836],
#          ...,
#          [0.4951, 0.5227, 0.4788,  ..., 0.4956, 0.4485, 0.3584],
#          [0.5184, 0.5203, 0.5533,  ..., 0.5456, 0.4574, 0.4388],
#          [0.4362, 0.4936, 0.4535,  ..., 0.5630, 0.4694, 0.4625]],
#
#         [[0.6258, 0.5361, 0.5293,  ..., 0.5208, 0.5529, 0.5522],
#          [0.5800, 0.4318, 0.4850,  ..., 0.4494, 0.6640, 0.5482],
#          [0.5195, 0.4965, 0.4719,  ..., 0.4404, 0.5990, 0.4140],
#          ...,
#          [0.5048, 0.6523, 0.5245,  ..., 0.3928, 0.4339, 0.4630],
#          [0.5555, 0.5918, 0.5447,  ..., 0.5745, 0.5429, 0.4673],
#          [0.4854, 0.5158, 0.4545,  ..., 0.4972, 0.5942, 0.3503]]])

# %%
gen_data.shape
# Out:
# torch.Size([30000, 1000, 21])

# %%
import pandas as pd
import torch


# Convert the PyTorch tensor to a NumPy array
synthetic_data = gen_data[:, -1, :]


# Convert the NumPy array to a pandas DataFrame
synthetic_df = pd.DataFrame(synthetic_data)

# Specify column names for the DataFrame
column_names = ['checking_status', 'duration', 'credit_history', 'purpose',
               'credit_amount', 'savings_status', 'employment',
               'installment_commitment', 'personal_status', 'other_parties',
               'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
               'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
               'foreign_worker', 'class']
synthetic_df.columns = column_names

# Now, synthetic_df contains the reshaped synthetic data in a pandas DataFrame with shape (30000, 21)

# %%
synthetic_df
# Out:
#        checking_status  duration  credit_history   purpose  credit_amount  \
# 0             0.478505  0.565905        0.490211  0.448236       0.472696
# 1             0.455474  0.493797        0.468848  0.423789       0.614694
# 2             0.494384  0.475684        0.506650  0.457652       0.485349
# 3             0.533222  0.443696        0.442589  0.345123       0.540093
# 4             0.491692  0.464167        0.475775  0.458381       0.501096
# ...                ...       ...             ...       ...            ...
# 29995         0.502836  0.474452        0.443233  0.367224       0.419281
# 29996         0.523987  0.560227        0.420824  0.502473       0.623851
# 29997         0.438200  0.527874        0.468171  0.444992       0.589658
# 29998         0.436174  0.493608        0.453452  0.472750       0.537618
# 29999         0.485447  0.515768        0.454519  0.393722       0.571448
#
#        savings_status  employment  installment_commitment  personal_status  \
# 0            0.521699    0.556739                0.504936         0.445567
# 1            0.450945    0.484393                0.501624         0.475776
# 2            0.443305    0.512519                0.428163         0.553646
# 3            0.411210    0.515047                0.495991         0.564177
# 4            0.437926    0.520942                0.547313         0.590374
# ...               ...         ...                     ...              ...
# 29995        0.435557    0.634173                0.429748         0.525056
# 29996        0.435940    0.487619                0.501224         0.470839
# 29997        0.391490    0.508548                0.540120         0.400107
# 29998        0.458524    0.527670                0.420408         0.528684
# 29999        0.301150    0.511963                0.444329         0.487285
#
#        other_parties  ...  property_magnitude       age  other_payment_plans  \
# 0           0.474532  ...            0.498832  0.440030             0.502045
# 1           0.536397  ...            0.554665  0.581273             0.449968
# 2           0.510674  ...            0.436791  0.497064             0.518429
# 3           0.492443  ...            0.404047  0.591348             0.419443
# 4           0.503895  ...            0.432216  0.554620             0.524405
# ...              ...  ...                 ...       ...                  ...
# 29995       0.504594  ...            0.460728  0.491926             0.469438
# 29996       0.550358  ...            0.486309  0.595213             0.446906
# 29997       0.520032  ...            0.504002  0.506881             0.518777
# 29998       0.510869  ...            0.437890  0.577642             0.507049
# 29999       0.493118  ...            0.467516  0.557110             0.490862
#
#         housing  existing_credits       job  num_dependents  own_telephone  \
# 0      0.575150          0.536195  0.552032        0.447722       0.575852
# 1      0.566813          0.486232  0.458741        0.398875       0.547526
# 2      0.518192          0.450595  0.516134        0.520200       0.498477
# 3      0.519134          0.469775  0.573944        0.462546       0.516776
# 4      0.537387          0.473601  0.484209        0.517816       0.546572
# ...         ...               ...       ...             ...            ...
# 29995  0.586156          0.464904  0.462628        0.427678       0.574569
# 29996  0.479065          0.477742  0.535207        0.439763       0.589492
# 29997  0.574175          0.428081  0.522217        0.484277       0.630850
# 29998  0.558102          0.441728  0.476728        0.445763       0.562974
# 29999  0.530920          0.467293  0.413824        0.469600       0.497223
#
#        foreign_worker     class
# 0            0.397606  0.502111
# 1            0.513937  0.466883
# 2            0.510671  0.484485
# 3            0.566685  0.523864
# 4            0.528586  0.514994
# ...               ...       ...
# 29995        0.494020  0.322354
# 29996        0.471735  0.473615
# 29997        0.477703  0.421251
# 29998        0.469395  0.462535
# 29999        0.594151  0.350280
#
# [30000 rows x 21 columns]

# %%
real_data_t
# Out:
#      checking_status  duration  credit_history  purpose  credit_amount  \
# 0             0.5310       6.0          0.6765   0.1400         1169.0
# 1             0.8025      48.0          0.2650   0.1400         5951.0
# 2             0.1970      12.0          0.6765   0.9200         2096.0
# 3             0.5310      42.0          0.2650   0.6045         7882.0
# 4             0.5310      24.0          0.8670   0.3970         4870.0
# ..               ...       ...             ...      ...            ...
# 995           0.1970      12.0          0.2650   0.6045         1736.0
# 996           0.5310      30.0          0.2650   0.7465         3857.0
# 997           0.1970      12.0          0.2650   0.1400          804.0
# 998           0.5310      45.0          0.2650   0.1400         1845.0
# 999           0.8025      45.0          0.6765   0.7465         4576.0
#
#      savings_status  employment  installment_commitment  personal_status  \
# 0            0.6945      0.4655                     4.0            0.274
# 1            0.3015      0.1695                     2.0            0.703
# 2            0.3015      0.6790                     2.0            0.274
# 3            0.3015      0.6790                     2.0            0.274
# 4            0.3015      0.1695                     3.0            0.274
# ..              ...         ...                     ...              ...
# 995          0.3015      0.6790                     3.0            0.703
# 996          0.3015      0.1695                     4.0            0.975
# 997          0.3015      0.4655                     4.0            0.274
# 998          0.3015      0.1695                     4.0            0.274
# 999          0.8375      0.9690                     3.0            0.274
#
#      other_parties  ...  property_magnitude   age  other_payment_plans  \
# 0           0.4535  ...               0.473  67.0                0.407
# 1           0.4535  ...               0.473  22.0                0.407
# 2           0.4535  ...               0.473  49.0                0.407
# 3           0.9330  ...               0.730  45.0                0.407
# 4           0.4535  ...               0.923  53.0                0.407
# ..             ...  ...                 ...   ...                  ...
# 995         0.4535  ...               0.473  31.0                0.407
# 996         0.4535  ...               0.730  40.0                0.407
# 997         0.4535  ...               0.166  38.0                0.407
# 998         0.4535  ...               0.923  23.0                0.407
# 999         0.4535  ...               0.166  27.0                0.407
#
#      housing  existing_credits    job  num_dependents  own_telephone  \
# 0     0.3565               2.0  0.315             1.0          0.798
# 1     0.3565               1.0  0.315             1.0          0.298
# 2     0.3565               1.0  0.730             2.0          0.298
# 3     0.9460               1.0  0.315             2.0          0.298
# 4     0.9460               2.0  0.315             2.0          0.298
# ..       ...               ...    ...             ...            ...
# 995   0.3565               1.0  0.730             1.0          0.298
# 996   0.3565               1.0  0.904             1.0          0.798
# 997   0.3565               1.0  0.315             1.0          0.298
# 998   0.9460               1.0  0.315             1.0          0.798
# 999   0.3565               1.0  0.315             1.0          0.298
#
#      foreign_worker  class
# 0            0.4815   0.35
# 1            0.4815   0.85
# 2            0.4815   0.35
# 3            0.4815   0.35
# 4            0.4815   0.85
# ..              ...    ...
# 995          0.4815   0.35
# 996          0.4815   0.35
# 997          0.4815   0.35
# 998          0.4815   0.85
# 999          0.4815   0.35
#
# [1000 rows x 21 columns]
