# %%
pip install sdv==1.0.0b1
# Out:
# ...
#      ---------------------------------------- 0.0/110.5 kB ? eta -:--:--
#      ---------- ---------------------------- 30.7/110.5 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 110.5/110.5 kB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/77.1 kB ? eta -:--:--
#      ---------------------------------------- 77.1/77.1 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/14.8 MB ? eta -:--:--
#       --------------------------------------- 0.2/14.8 MB 3.6 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/14.8 MB 4.0 MB/s eta 0:00:04
#      -- ------------------------------------- 0.9/14.8 MB 4.9 MB/s eta 0:00:03
#      --- ------------------------------------ 1.4/14.8 MB 6.5 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.7/14.8 MB 6.8 MB/s eta 0:00:02
# ...

# %%
import sdv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import sdv
#
# ModuleNotFoundError: No module named 'sdv'
