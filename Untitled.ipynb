# %%
import numpy as np
import pandas as pd
import sdv
import matplotlib.pyplot as plt

# %%
sdv.__version__
# Out:
# '1.0.0b1'

# %%
real_data=pd.read_csv('german_credit_data.csv')

# %% [markdown]
# # Gaussian Copula

# %%
from sdv.metadata import SingleTableMetadata #this is a function that creates metadata, tries to capture the datatypes 
                                              
metadata = SingleTableMetadata()#creating an empty data table
metadata.detect_from_csv(filepath='german_credit_data.csv')

# %%
metadata #checking metadata
# Out:
# {
#     "columns": {
#         "checking_status": {
#             "sdtype": "categorical"
#         },
#         "duration": {
#             "sdtype": "numerical"
#         },
#         "credit_history": {
#             "sdtype": "categorical"
#         },
#         "purpose": {
#             "sdtype": "categorical"
#         },
#         "credit_amount": {
#             "sdtype": "numerical"
#         },
#         "savings_status": {
#             "sdtype": "categorical"
#         },
#         "employment": {
#             "sdtype": "categorical"
#         },
#         "installment_commitment": {
#             "sdtype": "numerical"
#         },
#         "personal_status": {
#             "sdtype": "categorical"
#         },
#         "other_parties": {
#             "sdtype": "categorical"
#         },
#         "residence_since": {
#             "sdtype": "numerical"
#         },
#         "property_magnitude": {
#             "sdtype": "categorical"
#         },
#         "age": {
#             "sdtype": "numerical"
#         },
#         "other_payment_plans": {
#             "sdtype": "categorical"
#         },
#         "housing": {
#             "sdtype": "categorical"
#         },
#         "existing_credits": {
#             "sdtype": "numerical"
#         },
#         "job": {
#             "sdtype": "categorical"
#         },
#         "num_dependents": {
#             "sdtype": "numerical"
#         },
#         "own_telephone": {
#             "sdtype": "categorical"
#         },
#         "foreign_worker": {
#             "sdtype": "categorical"
#         },
#         "class": {
#             "sdtype": "categorical"
#         }
#     },
#     "METADATA_SPEC_VERSION": "SINGLE_TABLE_V1"
# }

# %%
metadata.validate() #validating for our synthesizer

# %%
from sdv.single_table import GaussianCopulaSynthesizer
synthesizer2 = GaussianCopulaSynthesizer(
    metadata, # required
    enforce_min_max_values=True,
    enforce_rounding=True,
    numerical_distributions = {
    'num_dependents': 'truncnorm',
    'existing_credits' : 'truncnorm',
         'housing' : 'gamma',
    'purpose': 'truncnorm',
        'savings_status': 'truncnorm'
    },
    default_distribution='beta'
)

# %%
synthesizer2.get_parameters()
# Out:
# {'enforce_min_max_values': True,
#  'enforce_rounding': True,
#  'numerical_distributions': {'num_dependents': 'truncnorm',
#   'existing_credits': 'truncnorm',
#   'housing': 'gamma',
#   'purpose': 'truncnorm',
#   'savings_status': 'truncnorm'},
#  'default_distribution': 'beta'}

# %%
synthesizer2.fit(real_data)
new_data2=synthesizer2.sample(30000)

# %%
#used for transforming datatypes to cont. var
transformers = synthesizer2.get_transformers()
transformers
# Out:
# {'checking_status': LabelEncoder(add_noise=True),
#  'duration': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'credit_history': LabelEncoder(add_noise=True),
#  'purpose': LabelEncoder(add_noise=True),
#  'credit_amount': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'savings_status': LabelEncoder(add_noise=True),
#  'employment': LabelEncoder(add_noise=True),
#  'installment_commitment': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'personal_status': LabelEncoder(add_noise=True),
#  'other_parties': LabelEncoder(add_noise=True),
#  'residence_since': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'property_magnitude': LabelEncoder(add_noise=True),
#  'age': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'other_payment_plans': LabelEncoder(add_noise=True),
#  'housing': LabelEncoder(add_noise=True),
#  'existing_credits': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'job': LabelEncoder(add_noise=True),
#  'num_dependents': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'own_telephone': LabelEncoder(add_noise=True),
#  'foreign_worker': LabelEncoder(add_noise=True),
#  'class': LabelEncoder(add_noise=True)}

# %%
processed_data = synthesizer2.preprocess(real_data)
processed_data
# Out:
# C:\Users\arnab\AppData\Local\Programs\Python\Python310\lib\site-packages\sdv\single_table\base.py:418: UserWarning: This model has already been fitted. To use the new preprocessed data, please refit the model using 'fit' or 'fit_processed_data'.
#   warnings.warn(
#      checking_status  duration  credit_history   purpose  credit_amount  \
# 0           0.135999       6.0        0.135999  0.135999         1169.0
# 1           1.435761      48.0        1.435761  0.435761         5951.0
# 2           2.433343      12.0        0.433343  1.433343         2096.0
# 3           0.913815      42.0        1.913815  2.913815         7882.0
# 4           0.990847      24.0        2.990847  3.990847         4870.0
# ..               ...       ...             ...       ...            ...
# 995         2.434825      12.0        1.434825  2.434825         1736.0
# 996         0.290422      30.0        1.290422  4.290422         3857.0
# 997         2.731553      12.0        1.731553  0.731553          804.0
# 998         0.927332      45.0        1.927332  0.927332         1845.0
# 999         1.665575      45.0        0.665575  4.665575         4576.0
#
#      savings_status  employment  installment_commitment  personal_status  \
# 0          0.135999    0.135999                     4.0         0.135999
# 1          1.435761    1.435761                     2.0         1.435761
# 2          1.433343    2.433343                     2.0         0.433343
# 3          1.913815    2.913815                     2.0         0.913815
# 4          1.990847    1.990847                     3.0         0.990847
# ..              ...         ...                     ...              ...
# 995        1.434825    2.434825                     3.0         1.434825
# 996        1.290422    1.290422                     4.0         2.290422
# 997        1.731553    0.731553                     4.0         0.731553
# 998        1.927332    1.927332                     4.0         0.927332
# 999        4.665575    3.665575                     3.0         0.665575
#
#      other_parties  ...  property_magnitude   age  other_payment_plans  \
# 0         0.135999  ...            0.135999  67.0             0.135999
# 1         0.435761  ...            0.435761  22.0             0.435761
# 2         0.433343  ...            0.433343  49.0             0.433343
# 3         1.913815  ...            1.913815  45.0             0.913815
# 4         0.990847  ...            2.990847  53.0             0.990847
# ..             ...  ...                 ...   ...                  ...
# 995       0.434825  ...            0.434825  31.0             0.434825
# 996       0.290422  ...            1.290422  40.0             0.290422
# 997       0.731553  ...            3.731553  38.0             0.731553
# 998       0.927332  ...            2.927332  23.0             0.927332
# 999       0.665575  ...            3.665575  27.0             0.665575
#
#       housing  existing_credits       job  num_dependents  own_telephone  \
# 0    0.135999               2.0  0.135999             1.0       0.135999
# 1    0.435761               1.0  0.435761             1.0       1.435761
# 2    0.433343               1.0  1.433343             2.0       1.433343
# 3    1.913815               1.0  0.913815             2.0       1.913815
# 4    1.990847               2.0  0.990847             2.0       1.990847
# ..        ...               ...       ...             ...            ...
# 995  0.434825               1.0  1.434825             1.0       1.434825
# 996  0.290422               1.0  2.290422             1.0       0.290422
# 997  0.731553               1.0  0.731553             1.0       1.731553
# 998  1.927332               1.0  0.927332             1.0       0.927332
# 999  0.665575               1.0  0.665575             1.0       1.665575
#
#      foreign_worker     class
# 0          0.135999  0.135999
# 1          0.435761  1.435761
# 2          0.433343  0.433343
# 3          0.913815  0.913815
# 4          0.990847  1.990847
# ..              ...       ...
# 995        0.434825  0.434825
# 996        0.290422  0.290422
# 997        0.731553  0.731553
# 998        0.927332  1.927332
# 999        0.665575  0.665575
#
# [1000 rows x 21 columns]

# %%
synthesizer2.fit_processed_data(processed_data)

# %%
synthesizer2.get_transformers()
# Out:
# {'checking_status': LabelEncoder(add_noise=True),
#  'duration': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'credit_history': LabelEncoder(add_noise=True),
#  'purpose': LabelEncoder(add_noise=True),
#  'credit_amount': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'savings_status': LabelEncoder(add_noise=True),
#  'employment': LabelEncoder(add_noise=True),
#  'installment_commitment': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'personal_status': LabelEncoder(add_noise=True),
#  'other_parties': LabelEncoder(add_noise=True),
#  'residence_since': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'property_magnitude': LabelEncoder(add_noise=True),
#  'age': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'other_payment_plans': LabelEncoder(add_noise=True),
#  'housing': LabelEncoder(add_noise=True),
#  'existing_credits': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'job': LabelEncoder(add_noise=True),
#  'num_dependents': FloatFormatter(learn_rounding_scheme=True, enforce_min_max_values=True),
#  'own_telephone': LabelEncoder(add_noise=True),
#  'foreign_worker': LabelEncoder(add_noise=True),
#  'class': LabelEncoder(add_noise=True)}

# %%
new_data= synthesizer2.sample(30000)
new_data.head()
# Out:
#   checking_status  duration                  credit_history   purpose  \
# 0              <0        12                   existing paid   repairs
# 1        0<=X<200        49  critical/other existing credit   new car
# 2        0<=X<200        43             no credits/all paid     other
# 3              <0        29  critical/other existing credit  radio/tv
# 4     no checking        14                   existing paid   new car
#
#    credit_amount    savings_status  employment  installment_commitment  \
# 0           5200  no known savings      4<=X<7                       2
# 1           8065              <100         >=7                       4
# 2           1933  no known savings      4<=X<7                       4
# 3           1434  no known savings         >=7                       3
# 4           3598       500<=X<1000  unemployed                       2
#
#       personal_status other_parties  ...  property_magnitude age  \
# 0         male single          none  ...      life insurance  37
# 1         male single          none  ...                 car  38
# 2  female div/dep/mar          none  ...   no known property  32
# 3        male div/sep          none  ...      life insurance  41
# 4        male div/sep          none  ...         real estate  38
#
#    other_payment_plans   housing existing_credits                 job  \
# 0                 none       own                1  unskilled resident
# 1                 none  for free                1             skilled
# 2                 none       own                2             skilled
# 3                 none       own                1             skilled
# 4                 bank  for free                2             skilled
#
#   num_dependents  own_telephone foreign_worker class
# 0              1           none            yes  good
# 1              2            yes            yes   bad
# 2              1           none            yes  good
# 3              1           none            yes  good
# 4              1           none            yes  good
#
# [5 rows x 21 columns]

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report1 = evaluate_quality(
    real_data,
    new_data,
    metadata
)
# Out:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.20s/it]
# Overall Quality Score: 85.7%
#
# Properties:
# Column Shapes: 89.26%
# Column Pair Trends: 82.15%

# %% [markdown]
# ## CTGAN

# %%
from sdv.single_table import CTGANSynthesizer

synthesizergan = CTGANSynthesizer(metadata, # required
    enforce_rounding=False,
    epochs=500,
    verbose=True)

# %%
synthesizergan.fit(real_data)
synthetic_dataCTGAN2 = synthesizergan.sample(num_rows=30000)
# Out:
# Epoch 1, Loss G:  1.3322,Loss D: -0.0127
# Epoch 2, Loss G:  1.2964,Loss D: -0.0490
# Epoch 3, Loss G:  1.3477,Loss D: -0.1445
# Epoch 4, Loss G:  1.3091,Loss D: -0.1784
# Epoch 5, Loss G:  1.2910,Loss D: -0.2555
# Epoch 6, Loss G:  1.2279,Loss D: -0.4052
# Epoch 7, Loss G:  1.1432,Loss D: -0.3808
# Epoch 8, Loss G:  1.0210,Loss D: -0.5624
# Epoch 9, Loss G:  0.9873,Loss D: -0.5773
# Epoch 10, Loss G:  0.7744,Loss D: -0.5989
# Epoch 11, Loss G:  0.6777,Loss D: -0.5594
# Epoch 12, Loss G:  0.5199,Loss D: -0.4566
# Epoch 13, Loss G:  0.2029,Loss D: -0.3634
# Epoch 14, Loss G:  0.0663,Loss D: -0.0391
# Epoch 15, Loss G:  0.1249,Loss D:  0.0199
# Epoch 16, Loss G:  0.0432,Loss D:  0.0343
# Epoch 17, Loss G: -0.0087,Loss D:  0.2160
# Epoch 18, Loss G: -0.0465,Loss D:  0.2520
# Epoch 19, Loss G: -0.0035,Loss D:  0.2109
# Epoch 20, Loss G: -0.1609,Loss D:  0.1481
# Epoch 21, Loss G:  0.0047,Loss D:  0.1295
# Epoch 22, Loss G:  0.0176,Loss D:  0.1696
# Epoch 23, Loss G:  0.1556,Loss D:  0.1438
# Epoch 24, Loss G:  0.0837,Loss D:  0.2291
# Epoch 25, Loss G: -0.0314,Loss D:  0.2402
# Epoch 26, Loss G:  0.2176,Loss D:  0.2449
# Epoch 27, Loss G:  0.1677,Loss D:  0.1946
# Epoch 28, Loss G:  0.2926,Loss D:  0.2354
# Epoch 29, Loss G:  0.0853,Loss D:  0.1515
# Epoch 30, Loss G:  0.2045,Loss D:  0.2270
# Epoch 31, Loss G:  0.2136,Loss D:  0.0813
# Epoch 32, Loss G:  0.3127,Loss D: -0.0596
# Epoch 33, Loss G:  0.2768,Loss D:  0.0877
# Epoch 34, Loss G:  0.2786,Loss D:  0.0543
# Epoch 35, Loss G:  0.3953,Loss D:  0.0663
# Epoch 36, Loss G:  0.1919,Loss D:  0.0023
# Epoch 37, Loss G:  0.2408,Loss D: -0.0099
# Epoch 38, Loss G:  0.0870,Loss D:  0.1075
# Epoch 39, Loss G:  0.1094,Loss D:  0.1595
# Epoch 40, Loss G:  0.2160,Loss D:  0.1826
# Epoch 41, Loss G: -0.0140,Loss D:  0.2530
# Epoch 42, Loss G: -0.0732,Loss D:  0.2663
# Epoch 43, Loss G: -0.1691,Loss D:  0.1606
# Epoch 44, Loss G: -0.0410,Loss D:  0.1737
# Epoch 45, Loss G:  0.1084,Loss D:  0.0544
# Epoch 46, Loss G: -0.0465,Loss D: -0.0461
# Epoch 47, Loss G: -0.0850,Loss D: -0.0114
# Epoch 48, Loss G:  0.0577,Loss D:  0.1076
# Epoch 49, Loss G:  0.0053,Loss D:  0.0636
# Epoch 50, Loss G: -0.1814,Loss D: -0.0523
# Epoch 51, Loss G: -0.0769,Loss D:  0.0938
# Epoch 52, Loss G: -0.2077,Loss D:  0.1545
# Epoch 53, Loss G: -0.2082,Loss D:  0.1879
# Epoch 54, Loss G: -0.1010,Loss D:  0.0323
# Epoch 55, Loss G: -0.1934,Loss D:  0.0995
# Epoch 56, Loss G: -0.0768,Loss D:  0.0626
# Epoch 57, Loss G: -0.1793,Loss D:  0.1007
# Epoch 58, Loss G: -0.1289,Loss D:  0.1196
# Epoch 59, Loss G: -0.0920,Loss D:  0.1066
# Epoch 60, Loss G: -0.2571,Loss D:  0.1191
# Epoch 61, Loss G: -0.0437,Loss D:  0.1349
# Epoch 62, Loss G: -0.1741,Loss D: -0.0374
# Epoch 63, Loss G:  0.0129,Loss D: -0.0345
# Epoch 64, Loss G: -0.0523,Loss D:  0.1015
# Epoch 65, Loss G: -0.2770,Loss D:  0.0437
# Epoch 66, Loss G: -0.2614,Loss D:  0.2433
# Epoch 67, Loss G: -0.3266,Loss D:  0.1240
# Epoch 68, Loss G: -0.2520,Loss D:  0.0624
# Epoch 69, Loss G: -0.3856,Loss D:  0.2186
# Epoch 70, Loss G: -0.1873,Loss D:  0.1732
# Epoch 71, Loss G: -0.3938,Loss D:  0.2176
# Epoch 72, Loss G: -0.3906,Loss D:  0.0960
# Epoch 73, Loss G: -0.2416,Loss D:  0.0949
# Epoch 74, Loss G: -0.1865,Loss D:  0.0745
# Epoch 75, Loss G: -0.2286,Loss D: -0.1018
# Epoch 76, Loss G: -0.2662,Loss D:  0.0522
# Epoch 77, Loss G: -0.0789,Loss D:  0.0371
# Epoch 78, Loss G: -0.1072,Loss D: -0.0809
# Epoch 79, Loss G: -0.1967,Loss D: -0.0309
# Epoch 80, Loss G: -0.2252,Loss D: -0.1378
# Epoch 81, Loss G: -0.3057,Loss D:  0.0289
# Epoch 82, Loss G: -0.4276,Loss D:  0.0703
# Epoch 83, Loss G: -0.3897,Loss D:  0.0215
# Epoch 84, Loss G: -0.3482,Loss D:  0.2522
# Epoch 85, Loss G: -0.3945,Loss D:  0.1645
# Epoch 86, Loss G: -0.3376,Loss D:  0.1755
# Epoch 87, Loss G: -0.4922,Loss D:  0.0185
# Epoch 88, Loss G: -0.3171,Loss D:  0.1027
# Epoch 89, Loss G: -0.2513,Loss D: -0.1031
# Epoch 90, Loss G: -0.1387,Loss D: -0.0316
# Epoch 91, Loss G: -0.1847,Loss D: -0.0498
# Epoch 92, Loss G: -0.0567,Loss D: -0.1545
# Epoch 93, Loss G: -0.0872,Loss D: -0.1206
# Epoch 94, Loss G: -0.0622,Loss D:  0.0482
# Epoch 95, Loss G: -0.0105,Loss D:  0.0182
# Epoch 96, Loss G: -0.0963,Loss D:  0.0519
# Epoch 97, Loss G: -0.1951,Loss D:  0.0864
# Epoch 98, Loss G: -0.3356,Loss D:  0.1388
# Epoch 99, Loss G: -0.3128,Loss D:  0.0492
# Epoch 100, Loss G: -0.5416,Loss D:  0.1981
# Epoch 101, Loss G: -0.4560,Loss D:  0.1429
# Epoch 102, Loss G: -0.3349,Loss D:  0.1196
# Epoch 103, Loss G: -0.4205,Loss D:  0.0731
# Epoch 104, Loss G: -0.4548,Loss D:  0.0733
# Epoch 105, Loss G: -0.5131,Loss D: -0.0750
# Epoch 106, Loss G: -0.3619,Loss D: -0.0926
# Epoch 107, Loss G: -0.3211,Loss D: -0.0684
# Epoch 108, Loss G: -0.4433,Loss D: -0.1828
# Epoch 109, Loss G: -0.4640,Loss D: -0.0343
# Epoch 110, Loss G: -0.5264,Loss D:  0.1006
# Epoch 111, Loss G: -0.6533,Loss D: -0.0100
# Epoch 112, Loss G: -0.6195,Loss D:  0.2247
# Epoch 113, Loss G: -0.5218,Loss D:  0.0559
# Epoch 114, Loss G: -0.5808,Loss D:  0.1736
# Epoch 115, Loss G: -0.6832,Loss D:  0.1067
# Epoch 116, Loss G: -0.5986,Loss D:  0.0391
# Epoch 117, Loss G: -0.4835,Loss D:  0.1347
# Epoch 118, Loss G: -0.4400,Loss D: -0.0212
# Epoch 119, Loss G: -0.4565,Loss D: -0.0244
# Epoch 120, Loss G: -0.3184,Loss D: -0.1051
# Epoch 121, Loss G: -0.2275,Loss D: -0.1389
# Epoch 122, Loss G: -0.2097,Loss D: -0.1736
# Epoch 123, Loss G: -0.3642,Loss D: -0.1361
# Epoch 124, Loss G: -0.1997,Loss D:  0.1284
# Epoch 125, Loss G: -0.2736,Loss D:  0.1034
# Epoch 126, Loss G: -0.5058,Loss D:  0.1928
# Epoch 127, Loss G: -0.5372,Loss D:  0.2489
# Epoch 128, Loss G: -0.4860,Loss D:  0.1574
# Epoch 129, Loss G: -0.5033,Loss D:  0.2589
# Epoch 130, Loss G: -0.5630,Loss D:  0.1063
# Epoch 131, Loss G: -0.5793,Loss D:  0.0397
# Epoch 132, Loss G: -0.4945,Loss D: -0.0802
# Epoch 133, Loss G: -0.3510,Loss D: -0.1064
# Epoch 134, Loss G: -0.3550,Loss D: -0.0748
# Epoch 135, Loss G: -0.4629,Loss D: -0.2521
# Epoch 136, Loss G: -0.4236,Loss D: -0.2770
# Epoch 137, Loss G: -0.4854,Loss D: -0.2878
# Epoch 138, Loss G: -0.5446,Loss D:  0.0894
# Epoch 139, Loss G: -0.6348,Loss D:  0.0255
# Epoch 140, Loss G: -0.7636,Loss D:  0.1291
# Epoch 141, Loss G: -0.9486,Loss D:  0.1639
# Epoch 142, Loss G: -1.0519,Loss D:  0.2031
# Epoch 143, Loss G: -1.1183,Loss D:  0.2878
# Epoch 144, Loss G: -0.8394,Loss D:  0.2162
# Epoch 145, Loss G: -0.8821,Loss D:  0.0828
# Epoch 146, Loss G: -0.7907,Loss D:  0.0327
# Epoch 147, Loss G: -0.8192,Loss D: -0.0172
# Epoch 148, Loss G: -0.5272,Loss D: -0.1183
# Epoch 149, Loss G: -0.4273,Loss D: -0.1688
# Epoch 150, Loss G: -0.4152,Loss D: -0.1354
# Epoch 151, Loss G: -0.4814,Loss D: -0.3144
# Epoch 152, Loss G: -0.4013,Loss D:  0.0386
# Epoch 153, Loss G: -0.6429,Loss D:  0.0374
# Epoch 154, Loss G: -0.6896,Loss D:  0.1790
# Epoch 155, Loss G: -0.7388,Loss D:  0.1763
# Epoch 156, Loss G: -0.9446,Loss D:  0.2594
# Epoch 157, Loss G: -0.9313,Loss D:  0.2043
# Epoch 158, Loss G: -0.9132,Loss D:  0.0890
# Epoch 159, Loss G: -0.8857,Loss D:  0.0640
# Epoch 160, Loss G: -0.8963,Loss D:  0.0298
# Epoch 161, Loss G: -0.6775,Loss D: -0.1343
# Epoch 162, Loss G: -0.7659,Loss D: -0.0801
# Epoch 163, Loss G: -0.7165,Loss D: -0.1383
# Epoch 164, Loss G: -0.7060,Loss D: -0.2297
# Epoch 165, Loss G: -0.8262,Loss D: -0.1446
# Epoch 166, Loss G: -0.9417,Loss D: -0.1468
# Epoch 167, Loss G: -0.8145,Loss D: -0.0479
# Epoch 168, Loss G: -0.9747,Loss D:  0.1155
# Epoch 169, Loss G: -0.8952,Loss D:  0.1600
# Epoch 170, Loss G: -1.0063,Loss D:  0.2008
# Epoch 171, Loss G: -0.9905,Loss D: -0.0760
# Epoch 172, Loss G: -0.9710,Loss D:  0.0219
# Epoch 173, Loss G: -0.9093,Loss D:  0.0680
# Epoch 174, Loss G: -0.7310,Loss D:  0.0507
# Epoch 175, Loss G: -0.9665,Loss D: -0.0595
# Epoch 176, Loss G: -1.0096,Loss D:  0.0639
# Epoch 177, Loss G: -1.1028,Loss D:  0.0147
# Epoch 178, Loss G: -1.1773,Loss D:  0.1055
# Epoch 179, Loss G: -1.1366,Loss D:  0.1365
# Epoch 180, Loss G: -1.1918,Loss D:  0.0573
# Epoch 181, Loss G: -1.1751,Loss D:  0.0744
# Epoch 182, Loss G: -1.1514,Loss D:  0.1263
# Epoch 183, Loss G: -1.0983,Loss D: -0.0369
# Epoch 184, Loss G: -1.3031,Loss D: -0.1301
# Epoch 185, Loss G: -1.1916,Loss D: -0.0643
# Epoch 186, Loss G: -1.2074,Loss D: -0.1000
# Epoch 187, Loss G: -1.3779,Loss D: -0.0782
# Epoch 188, Loss G: -1.3882,Loss D: -0.0708
# Epoch 498, Loss G: -2.6892,Loss D:  0.1498
# Epoch 499, Loss G: -2.7022,Loss D:  0.0875
# Epoch 500, Loss G: -2.7309,Loss D:  0.0305

# %%
synthetic_dataCTGAN2.head()
# Out:
#   checking_status  duration      credit_history              purpose  \
# 0              <0        47       existing paid              repairs
# 1              <0        24       existing paid            education
# 2              <0        17  delayed previously  furniture/equipment
# 3           >=200        46       existing paid             radio/tv
# 4              <0        18       existing paid  furniture/equipment
#
#    credit_amount savings_status employment  installment_commitment  \
# 0            250     100<=X<500     4<=X<7                       4
# 1            922           <100     1<=X<4                       2
# 2            283           <100         <1                       4
# 3           1264     100<=X<500        >=7                       4
# 4            250           <100        >=7                       4
#
#       personal_status other_parties  ...  property_magnitude age  \
# 0  female div/dep/mar          none  ...                 car  31
# 1         male single          none  ...                 car  73
# 2        male mar/wid          none  ...                 car  28
# 3  female div/dep/mar          none  ...      life insurance  19
# 4  female div/dep/mar          none  ...      life insurance  19
#
#    other_payment_plans housing existing_credits                        job  \
# 0                 none     own                2    unemp/unskilled non res
# 1               stores    rent                1  high qualif/self emp/mgmt
# 2                 none    rent                1         unskilled resident
# 3                 none    rent                2         unskilled resident
# 4                 none    rent                1  high qualif/self emp/mgmt
#
#   num_dependents  own_telephone foreign_worker class
# 0              2           none            yes   bad
# 1              1           none            yes   bad
# 2              1            yes            yes  good
# 3              1           none            yes  good
# 4              1           none            yes  good
#
# [5 rows x 21 columns]

# %%
processed_datagan = synthesizergan.preprocess(real_data)
processed_datagan
# Out:
# C:\Users\arnab\AppData\Local\Programs\Python\Python310\lib\site-packages\sdv\single_table\base.py:418: UserWarning: This model has already been fitted. To use the new preprocessed data, please refit the model using 'fit' or 'fit_processed_data'.
#   warnings.warn(
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# 2              education         2096.0              <100      4<=X<7
# 3    furniture/equipment         7882.0              <100      4<=X<7
# 4                new car         4870.0              <100      1<=X<4
# ..                   ...            ...               ...         ...
# 995  furniture/equipment         1736.0              <100      4<=X<7
# 996             used car         3857.0              <100      1<=X<4
# 997             radio/tv          804.0              <100         >=7
# 998             radio/tv         1845.0              <100      1<=X<4
# 999             used car         4576.0        100<=X<500  unemployed
#
#      installment_commitment     personal_status other_parties  ...  \
# 0                       4.0         male single          none  ...
# 1                       2.0  female div/dep/mar          none  ...
# 2                       2.0         male single          none  ...
# 3                       2.0         male single     guarantor  ...
# 4                       3.0         male single          none  ...
# ..                      ...                 ...           ...  ...
# 995                     3.0  female div/dep/mar          none  ...
# 996                     4.0        male div/sep          none  ...
# 997                     4.0         male single          none  ...
# 998                     4.0         male single          none  ...
# 999                     3.0         male single          none  ...
#
#      property_magnitude   age  other_payment_plans   housing existing_credits  \
# 0           real estate  67.0                 none       own              2.0
# 1           real estate  22.0                 none       own              1.0
# 2           real estate  49.0                 none       own              1.0
# 3        life insurance  45.0                 none  for free              1.0
# 4     no known property  53.0                 none  for free              2.0
# ..                  ...   ...                  ...       ...              ...
# 995         real estate  31.0                 none       own              1.0
# 996      life insurance  40.0                 none       own              1.0
# 997                 car  38.0                 none       own              1.0
# 998   no known property  23.0                 none  for free              1.0
# 999                 car  27.0                 none       own              1.0
#
#                            job num_dependents  own_telephone foreign_worker  \
# 0                      skilled            1.0            yes            yes
# 1                      skilled            1.0           none            yes
# 2           unskilled resident            2.0           none            yes
# 3                      skilled            2.0           none            yes
# 4                      skilled            2.0           none            yes
# ..                         ...            ...            ...            ...
# 995         unskilled resident            1.0           none            yes
# 996  high qualif/self emp/mgmt            1.0            yes            yes
# 997                    skilled            1.0           none            yes
# 998                    skilled            1.0            yes            yes
# 999                    skilled            1.0           none            yes
#
#     class
# 0    good
# 1     bad
# 2    good
# 3    good
# 4     bad
# ..    ...
# 995  good
# 996  good
# 997  good
# 998   bad
# 999  good
#
# [1000 rows x 21 columns]

# %%
synthesizergan.fit_processed_data(processed_datagan)
# Out:
# Epoch 1, Loss G:  1.3885,Loss D: -0.0355
# Epoch 2, Loss G:  1.3830,Loss D: -0.0500
# Epoch 3, Loss G:  1.3876,Loss D: -0.1130
# Epoch 4, Loss G:  1.4189,Loss D: -0.1727
# Epoch 5, Loss G:  1.3836,Loss D: -0.2727
# Epoch 6, Loss G:  1.3413,Loss D: -0.3117
# Epoch 7, Loss G:  1.2220,Loss D: -0.3709
# Epoch 8, Loss G:  1.2083,Loss D: -0.4493
# Epoch 9, Loss G:  1.1080,Loss D: -0.4920
# Epoch 10, Loss G:  1.0752,Loss D: -0.3648
# Epoch 11, Loss G:  0.8564,Loss D: -0.3746
# Epoch 12, Loss G:  0.8079,Loss D: -0.3033
# Epoch 13, Loss G:  0.6320,Loss D:  0.0683
# Epoch 14, Loss G:  0.6442,Loss D: -0.0468
# Epoch 15, Loss G:  0.4012,Loss D: -0.0434
# Epoch 16, Loss G:  0.3678,Loss D:  0.0162
# Epoch 17, Loss G:  0.3886,Loss D:  0.0078
# Epoch 18, Loss G:  0.3238,Loss D:  0.2275
# Epoch 19, Loss G:  0.4628,Loss D:  0.1786
# Epoch 20, Loss G:  0.5868,Loss D:  0.1647
# Epoch 21, Loss G:  0.5387,Loss D:  0.1263
# Epoch 22, Loss G:  0.5730,Loss D:  0.2560
# Epoch 23, Loss G:  0.6856,Loss D:  0.0379
# Epoch 24, Loss G:  0.7840,Loss D:  0.1169
# Epoch 25, Loss G:  0.7065,Loss D:  0.1417
# Epoch 26, Loss G:  0.7368,Loss D:  0.0014
# Epoch 27, Loss G:  0.6686,Loss D:  0.0930
# Epoch 28, Loss G:  0.7776,Loss D:  0.0333
# Epoch 132, Loss G: -0.6601,Loss D:  0.1890
# Epoch 133, Loss G: -0.5961,Loss D:  0.2649
# Epoch 134, Loss G: -0.6682,Loss D:  0.1720
# Epoch 135, Loss G: -0.6059,Loss D:  0.0775
# Epoch 136, Loss G: -0.6780,Loss D:  0.1071
# Epoch 137, Loss G: -0.4983,Loss D:  0.0233
# Epoch 138, Loss G: -0.3933,Loss D: -0.0330
# Epoch 139, Loss G: -0.3306,Loss D: -0.1398
# Epoch 140, Loss G: -0.3592,Loss D: -0.1244
# Epoch 141, Loss G: -0.3766,Loss D: -0.1564
# Epoch 142, Loss G: -0.4876,Loss D: -0.1255
# Epoch 143, Loss G: -0.5264,Loss D:  0.0991
# Epoch 144, Loss G: -0.6235,Loss D:  0.1377
# Epoch 145, Loss G: -0.6379,Loss D:  0.1760
# Epoch 146, Loss G: -0.7016,Loss D:  0.1296
# Epoch 147, Loss G: -0.6560,Loss D:  0.1957
# Epoch 148, Loss G: -0.6190,Loss D:  0.0476
# Epoch 149, Loss G: -0.5378,Loss D: -0.1427
# Epoch 150, Loss G: -0.5910,Loss D: -0.1374
# Epoch 151, Loss G: -0.4735,Loss D: -0.1843
# Epoch 152, Loss G: -0.5058,Loss D: -0.1810
# Epoch 153, Loss G: -0.5075,Loss D: -0.1615
# Epoch 154, Loss G: -0.5102,Loss D: -0.0773
# Epoch 155, Loss G: -0.7350,Loss D: -0.0346
# Epoch 156, Loss G: -0.7758,Loss D:  0.0898
# Epoch 157, Loss G: -0.8500,Loss D:  0.1944
# Epoch 158, Loss G: -0.9696,Loss D:  0.1939
# Epoch 159, Loss G: -0.8307,Loss D:  0.0786
# Epoch 160, Loss G: -0.8290,Loss D:  0.0995
# Epoch 161, Loss G: -0.6932,Loss D:  0.0620
# Epoch 162, Loss G: -0.6829,Loss D:  0.0646
# Epoch 163, Loss G: -0.7481,Loss D:  0.0600
# Epoch 164, Loss G: -0.6174,Loss D: -0.0888
# Epoch 165, Loss G: -0.7597,Loss D:  0.0303
# Epoch 166, Loss G: -0.7213,Loss D:  0.0071
# Epoch 167, Loss G: -0.7257,Loss D:  0.0461
# Epoch 168, Loss G: -0.7823,Loss D: -0.0151
# Epoch 169, Loss G: -0.7513,Loss D:  0.0219
# Epoch 170, Loss G: -0.7203,Loss D: -0.1995
# Epoch 171, Loss G: -0.6417,Loss D: -0.2232
# Epoch 172, Loss G: -0.6866,Loss D: -0.3019
# Epoch 173, Loss G: -0.6114,Loss D: -0.0848
# Epoch 174, Loss G: -0.8852,Loss D: -0.0057
# Epoch 175, Loss G: -0.7930,Loss D: -0.0680
# Epoch 176, Loss G: -0.9146,Loss D:  0.0780
# Epoch 177, Loss G: -1.0491,Loss D:  0.1749
# Epoch 178, Loss G: -1.0552,Loss D:  0.1218
# Epoch 179, Loss G: -1.0419,Loss D:  0.1895
# Epoch 180, Loss G: -1.0986,Loss D:  0.0185
# Epoch 181, Loss G: -1.0712,Loss D:  0.1487
# Epoch 182, Loss G: -1.0172,Loss D:  0.0646
# Epoch 183, Loss G: -1.0223,Loss D:  0.0393
# Epoch 493, Loss G: -2.6694,Loss D: -0.0413
# Epoch 494, Loss G: -2.5978,Loss D: -0.1843
# Epoch 495, Loss G: -2.6744,Loss D: -0.1278
# Epoch 496, Loss G: -2.6099,Loss D:  0.0552
# Epoch 497, Loss G: -2.5276,Loss D: -0.0848
# Epoch 498, Loss G: -2.6948,Loss D: -0.1133
# Epoch 499, Loss G: -2.7831,Loss D:  0.0042
# Epoch 500, Loss G: -2.7507,Loss D:  0.0880

# %%
gan_data= synthesizer2.sample(30000)
gan_data.head()
# Out:
#   checking_status  duration      credit_history   purpose  credit_amount  \
# 0              <0         7       existing paid   new car           1500
# 1     no checking         9  delayed previously   new car           3815
# 2     no checking        24       existing paid  radio/tv           5764
# 3     no checking        23       existing paid  business           4967
# 4              <0        28       existing paid  radio/tv           1409
#
#      savings_status employment  installment_commitment personal_status  \
# 0  no known savings     4<=X<7                       3     male single
# 1            >=1000        >=7                       3     male single
# 2       500<=X<1000         <1                       1     male single
# 3              <100     1<=X<4                       3     male single
# 4  no known savings        >=7                       4     male single
#
#   other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 0          none  ...         real estate  28                 bank     own
# 1          none  ...         real estate  56                 none     own
# 2          none  ...      life insurance  30                 none     own
# 3          none  ...   no known property  31                 none     own
# 4          none  ...         real estate  45                 none    rent
#
#   existing_credits                 job num_dependents  own_telephone  \
# 0                2             skilled              1            yes
# 1                2             skilled              1            yes
# 2                2  unskilled resident              1            yes
# 3                2  unskilled resident              1            yes
# 4                1  unskilled resident              1            yes
#
#   foreign_worker class
# 0            yes  good
# 1            yes  good
# 2            yes  good
# 3            yes   bad
# 4            yes   bad
#
# [5 rows x 21 columns]

# %%
from sdv.evaluation.single_table import evaluate_quality

quality_report1 = evaluate_quality(
    real_data,
    gan_data,
    metadata
)
# Out:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.21it/s]
# Overall Quality Score: 85.72%
#
# Properties:
# Column Shapes: 89.26%
# Column Pair Trends: 82.17%

# %%
import sdv
from sdv.evaluation.single_table import evaluate_quality
from rdt import HyperTransformer
from rdt.transformers.categorical import LabelEncoder

def hybrid(real_data,df1,df2,metadata):
    print("First dataset quality score:")
    quality_report1 = evaluate_quality(
    real_data,
    df1,
    metadata)
    print("Second dataset quality score:")
    quality_report2 = evaluate_quality(
    real_data,
    df2,
    metadata)
    tab1=quality_report1.get_details('Column Shapes')
    tab2=quality_report2.get_details('Column Shapes')
    print("--------------First dataset report:-------------")
    print(tab1)
    print("--------------Second dataset report:------------")
    print(tab2)
    print("------------- Combined Quality score------------")
    tab1['Quality Score_1']=tab1['Quality Score']
    tab1['Quality Score_2']=tab2['Quality Score']
    tab1=tab1.drop('Quality Score',axis=1)
    print(tab1)
    #conversion of data
    
    ht = HyperTransformer()
    ht.detect_initial_config(data=df1)
    ht.remove_transformers_by_sdtype(sdtype='numerical')
    
    #Transformaer update(only for those variable that are not of good quality)
    col=df1.columns
    col1 =[i for i in col if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] < tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]]  
    # do not transform the credit_card or age columns
    ht.remove_transformers(column_names=col1)
    # do not transform any categorical columns in the dataset
    ht.remove_transformers_by_sdtype(sdtype='numerical')
    config = ht.get_config()
    

    print("Name of columns for which transformation have  been used:")
    col=[i for i in col if i not in col1]
    print(col)
    for feature in col:
        if config["transformers"][feature].__class__.__name__ == 'FrequencyEncoder':
            config["transformers"][feature] = LabelEncoder()

    print(config)
    ht.set_config(config)
    
    config = ht.get_config()
    print("Details of transformation22")
    print(config)
    #merging datasets 
    
    
    ht.fit(df2)
    transformed_df2 = ht.transform(df2)
    ht.fit(df1)
    transformed_df1 = ht.transform(df1)
    
    dff2=transformed_df2
    dff1=transformed_df1
    for i in col:
        if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] > tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]:
            dff2=dff2.sort_values(by=[i])
            dff1=dff1.sort_values(by=[i])
            dff2[i]=dff1[i]
    #reversing conversion
    
    reversed_dff = ht.reverse_transform(dff2)
    
    
    print("Hybrid quality score")
    quality_report4 = evaluate_quality(
    real_data,
    reversed_dff,
    metadata) 
    
    #qualityscore
    tab3=quality_report4.get_details('Column Shapes')
    print("Hybrid dataset report:")
    print(tab3)
    print(" Combined Quality score")
    tab1['Quality Score_3']=tab3['Quality Score']
    
    
    return tab1
hybrid(real_data,new_data,gan_data,metadata)
# Out:
# First dataset quality score:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.25it/s]
# Overall Quality Score: 85.7%
#
# Properties:
# Column Shapes: 89.26%
# Column Pair Trends: 82.15%
# Second dataset quality score:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.30it/s]
# Overall Quality Score: 85.72%
#
# Properties:
# Column Shapes: 89.26%
# Column Pair Trends: 82.17%
# --------------First dataset report:-------------
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.909833
# 1            credit_amount  KSComplement       0.936433
# 2   installment_commitment  KSComplement       0.950000
# 3          residence_since  KSComplement       0.928500
# 4                      age  KSComplement       0.977533
# 5         existing_credits  KSComplement       0.889767
# 6           num_dependents  KSComplement       0.933767
# 7          checking_status  TVComplement       0.859400
# 8           credit_history  TVComplement       0.811000
# 9                  purpose  TVComplement       0.803933
# 10          savings_status  TVComplement       0.650533
# 11              employment  TVComplement       0.848267
# 12         personal_status  TVComplement       0.912400
# 13           other_parties  TVComplement       0.884900
# 14      property_magnitude  TVComplement       0.940600
# 15     other_payment_plans  TVComplement       0.930800
# 16                 housing  TVComplement       0.860333
# 17                     job  TVComplement       0.898900
# 18           own_telephone  TVComplement       0.959700
# 19          foreign_worker  TVComplement       0.923233
# 20                   class  TVComplement       0.933967
# --------------Second dataset report:------------
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.900367
# 1            credit_amount  KSComplement       0.935100
# 2   installment_commitment  KSComplement       0.952033
# 3          residence_since  KSComplement       0.931400
# 4                      age  KSComplement       0.978367
# 5         existing_credits  KSComplement       0.889767
# 6           num_dependents  KSComplement       0.939967
# 7          checking_status  TVComplement       0.865200
# 8           credit_history  TVComplement       0.814600
# 9                  purpose  TVComplement       0.807667
# 10          savings_status  TVComplement       0.643233
# 11              employment  TVComplement       0.848033
# 12         personal_status  TVComplement       0.912500
# 13           other_parties  TVComplement       0.889367
# 14      property_magnitude  TVComplement       0.940433
# 15     other_payment_plans  TVComplement       0.924533
# 16                 housing  TVComplement       0.861100
# 17                     job  TVComplement       0.894567
# 18           own_telephone  TVComplement       0.959900
# 19          foreign_worker  TVComplement       0.922767
# 20                   class  TVComplement       0.934200
# ------------- Combined Quality score------------
#                     Column        Metric  Quality Score_1  Quality Score_2
# 0                 duration  KSComplement         0.909833         0.900367
# 1            credit_amount  KSComplement         0.936433         0.935100
# 2   installment_commitment  KSComplement         0.950000         0.952033
# 3          residence_since  KSComplement         0.928500         0.931400
# 4                      age  KSComplement         0.977533         0.978367
# 5         existing_credits  KSComplement         0.889767         0.889767
# 6           num_dependents  KSComplement         0.933767         0.939967
# 7          checking_status  TVComplement         0.859400         0.865200
# 8           credit_history  TVComplement         0.811000         0.814600
# 9                  purpose  TVComplement         0.803933         0.807667
# 10          savings_status  TVComplement         0.650533         0.643233
# 11              employment  TVComplement         0.848267         0.848033
# 12         personal_status  TVComplement         0.912400         0.912500
# 13           other_parties  TVComplement         0.884900         0.889367
# 14      property_magnitude  TVComplement         0.940600         0.940433
# 15     other_payment_plans  TVComplement         0.930800         0.924533
# 16                 housing  TVComplement         0.860333         0.861100
# 17                     job  TVComplement         0.898900         0.894567
# 18           own_telephone  TVComplement         0.959700         0.959900
# 19          foreign_worker  TVComplement         0.923233         0.922767
# 20                   class  TVComplement         0.933967         0.934200
# Name of columns for which transformation have  been used:
# ['duration', 'credit_amount', 'savings_status', 'employment', 'property_magnitude', 'other_payment_plans', 'existing_credits', 'job', 'foreign_worker']
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": None,
#         "duration": None,
#         "credit_history": None,
#         "purpose": None,
#         "credit_amount": None,
#         "savings_status": LabelEncoder(),
#         "employment": LabelEncoder(),
#         "installment_commitment": None,
#         "personal_status": None,
#         "other_parties": None,
#         "residence_since": None,
#         "property_magnitude": LabelEncoder(),
#         "age": None,
#         "other_payment_plans": LabelEncoder(),
#         "housing": None,
#         "existing_credits": None,
#         "job": LabelEncoder(),
#         "num_dependents": None,
#         "own_telephone": None,
#         "foreign_worker": LabelEncoder(),
#         "class": None
#     }
# }
# Details of transformation22
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": None,
#         "duration": None,
#         "credit_history": None,
#         "purpose": None,
#         "credit_amount": None,
#         "savings_status": LabelEncoder(),
#         "employment": LabelEncoder(),
#         "installment_commitment": None,
#         "personal_status": None,
#         "other_parties": None,
#         "residence_since": None,
#         "property_magnitude": LabelEncoder(),
#         "age": None,
#         "other_payment_plans": LabelEncoder(),
#         "housing": None,
#         "existing_credits": None,
#         "job": LabelEncoder(),
#         "num_dependents": None,
#         "own_telephone": None,
#         "foreign_worker": LabelEncoder(),
#         "class": None
#     }
# }
# Hybrid quality score
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.17it/s]
# Overall Quality Score: 85.74%
#
# Properties:
# Column Shapes: 89.4%
# Column Pair Trends: 82.08%
# Hybrid dataset report:
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.909833
# 1            credit_amount  KSComplement       0.936433
# 2   installment_commitment  KSComplement       0.952033
# 3          residence_since  KSComplement       0.931400
# 4                      age  KSComplement       0.978367
# 5         existing_credits  KSComplement       0.889767
# 6           num_dependents  KSComplement       0.939967
# 7          checking_status  TVComplement       0.865200
# 8           credit_history  TVComplement       0.814600
# 9                  purpose  TVComplement       0.807667
# 10          savings_status  TVComplement       0.650533
# 11              employment  TVComplement       0.848267
# 12         personal_status  TVComplement       0.912500
# 13           other_parties  TVComplement       0.889367
# 14      property_magnitude  TVComplement       0.940600
# 15     other_payment_plans  TVComplement       0.930800
# 16                 housing  TVComplement       0.861100
# 17                     job  TVComplement       0.898900
# 18           own_telephone  TVComplement       0.959900
# 19          foreign_worker  TVComplement       0.923233
# 20                   class  TVComplement       0.934200
#  Combined Quality score
#                     Column        Metric  Quality Score_1  Quality Score_2  \
# 0                 duration  KSComplement         0.909833         0.900367
# 1            credit_amount  KSComplement         0.936433         0.935100
# 2   installment_commitment  KSComplement         0.950000         0.952033
# 3          residence_since  KSComplement         0.928500         0.931400
# 4                      age  KSComplement         0.977533         0.978367
# 5         existing_credits  KSComplement         0.889767         0.889767
# 6           num_dependents  KSComplement         0.933767         0.939967
# 7          checking_status  TVComplement         0.859400         0.865200
# 8           credit_history  TVComplement         0.811000         0.814600
# 9                  purpose  TVComplement         0.803933         0.807667
# 10          savings_status  TVComplement         0.650533         0.643233
# 11              employment  TVComplement         0.848267         0.848033
# 12         personal_status  TVComplement         0.912400         0.912500
# 13           other_parties  TVComplement         0.884900         0.889367
# 14      property_magnitude  TVComplement         0.940600         0.940433
# 15     other_payment_plans  TVComplement         0.930800         0.924533
# 16                 housing  TVComplement         0.860333         0.861100
# 17                     job  TVComplement         0.898900         0.894567
# 18           own_telephone  TVComplement         0.959700         0.959900
# 19          foreign_worker  TVComplement         0.923233         0.922767
# 20                   class  TVComplement         0.933967         0.934200
#
#     Quality Score_3
# 0          0.909833
# 1          0.936433
# 2          0.952033
# 3          0.931400
# 4          0.978367
# 5          0.889767
# 6          0.939967
# 7          0.865200
# 8          0.814600
# 9          0.807667
# 10         0.650533
# 11         0.848267
# 12         0.912500
# 13         0.889367
# 14         0.940600
# 15         0.930800
# 16         0.861100
# 17         0.898900
# 18         0.959900
# 19         0.923233
# 20         0.934200

# %%
new_data2=pd.read_csv('new_data2.csv')
synthetic_dataCTGAN=pd.read_csv('synthetic_dataCTGAN.csv')

# %%
new_data2= new_data2.drop(new_data2.columns[[0]],axis=1)
new_data2
synthetic_dataCTGAN=synthetic_dataCTGAN.drop(synthetic_dataCTGAN.columns[[0]],axis=1)

# %%
new_data2
# Out:
#       checking_status  duration                  credit_history  \
# 0            0<=X<200        10  critical/other existing credit
# 1            0<=X<200        12                   existing paid
# 2               >=200        11  critical/other existing credit
# 3                  <0         8                   existing paid
# 4            0<=X<200         8  critical/other existing credit
# ...               ...       ...                             ...
# 29995        0<=X<200        21  critical/other existing credit
# 29996              <0        13              delayed previously
# 29997              <0         6                   existing paid
# 29998              <0         7              delayed previously
# 29999     no checking        19                   existing paid
#
#                    purpose  credit_amount    savings_status  employment  \
# 0                education           1789              <100      4<=X<7
# 1                 used car           1739            >=1000          <1
# 2      furniture/equipment            568              <100  unemployed
# 3      furniture/equipment           1230       500<=X<1000  unemployed
# 4      furniture/equipment           2817  no known savings      4<=X<7
# ...                    ...            ...               ...         ...
# 29995  furniture/equipment           1388              <100  unemployed
# 29996             business           1863  no known savings      1<=X<4
# 29997             radio/tv           1828  no known savings      4<=X<7
# 29998              new car           3604       500<=X<1000         >=7
# 29999              repairs           1782  no known savings      4<=X<7
#
#        installment_commitment     personal_status other_parties  ...  \
# 0                           4        male div/sep          none  ...
# 1                           1  female div/dep/mar          none  ...
# 2                           3  female div/dep/mar          none  ...
# 3                           4        male div/sep     guarantor  ...
# 4                           1  female div/dep/mar          none  ...
# ...                       ...                 ...           ...  ...
# 29995                       4         male single          none  ...
# 29996                       4         male single          none  ...
# 29997                       1         male single          none  ...
# 29998                       1         male single          none  ...
# 29999                       1        male div/sep     guarantor  ...
#
#        property_magnitude age  other_payment_plans   housing existing_credits  \
# 0                     car  42                 bank       own                1
# 1             real estate  30                 none       own                1
# 2             real estate  30                 none       own                2
# 3                     car  55                 none  for free                1
# 4                     car  42                 none       own                2
# ...                   ...  ..                  ...       ...              ...
# 29995   no known property  49                 none       own                2
# 29996                 car  32                 none       own                2
# 29997         real estate  31                 bank       own                1
# 29998   no known property  24                 none  for free                1
# 29999         real estate  37                 none  for free                2
#
#                              job num_dependents  own_telephone foreign_worker  \
# 0      high qualif/self emp/mgmt              1           none             no
# 1             unskilled resident              2           none            yes
# 2                        skilled              1            yes            yes
# 3      high qualif/self emp/mgmt              1           none             no
# 4                        skilled              1            yes            yes
# ...                          ...            ...            ...            ...
# 29995                    skilled              1            yes            yes
# 29996                    skilled              2            yes            yes
# 29997                    skilled              1           none            yes
# 29998                    skilled              2           none            yes
# 29999         unskilled resident              1           none             no
#
#       class
# 0       bad
# 1      good
# 2       bad
# 3       bad
# 4      good
# ...     ...
# 29995  good
# 29996   bad
# 29997  good
# 29998  good
# 29999   bad
#
# [30000 rows x 21 columns]

# %%
hybrid(real_data,new_data2,synthetic_dataCTGAN,metadata)
# Out:
# First dataset quality score:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.09it/s]
# Overall Quality Score: 85.47%
#
# Properties:
# Column Shapes: 89.03%
# Column Pair Trends: 81.9%
# Second dataset quality score:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.31it/s]
# Overall Quality Score: 87.74%
#
# Properties:
# Column Shapes: 89.88%
# Column Pair Trends: 85.59%
# --------------First dataset report:-------------
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.900233
# 1            credit_amount  KSComplement       0.939000
# 2   installment_commitment  KSComplement       0.951000
# 3          residence_since  KSComplement       0.927133
# 4                      age  KSComplement       0.977800
# 5         existing_credits  KSComplement       0.883900
# 6           num_dependents  KSComplement       0.934433
# 7          checking_status  TVComplement       0.859067
# 8           credit_history  TVComplement       0.812833
# 9                  purpose  TVComplement       0.803333
# 10          savings_status  TVComplement       0.646467
# 11              employment  TVComplement       0.823167
# 12         personal_status  TVComplement       0.914600
# 13           other_parties  TVComplement       0.883467
# 14      property_magnitude  TVComplement       0.941000
# 15     other_payment_plans  TVComplement       0.919667
# 16                 housing  TVComplement       0.863600
# 17                     job  TVComplement       0.905000
# 18           own_telephone  TVComplement       0.963500
# 19          foreign_worker  TVComplement       0.911667
# 20                   class  TVComplement       0.936167
# --------------Second dataset report:------------
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.866600
# 1            credit_amount  KSComplement       0.592633
# 2   installment_commitment  KSComplement       0.896733
# 3          residence_since  KSComplement       0.927200
# 4                      age  KSComplement       0.870700
# 5         existing_credits  KSComplement       0.779533
# 6           num_dependents  KSComplement       0.879267
# 7          checking_status  TVComplement       0.874200
# 8           credit_history  TVComplement       0.946100
# 9                  purpose  TVComplement       0.902133
# 10          savings_status  TVComplement       0.968933
# 11              employment  TVComplement       0.936400
# 12         personal_status  TVComplement       0.937733
# 13           other_parties  TVComplement       0.939400
# 14      property_magnitude  TVComplement       0.919867
# 15     other_payment_plans  TVComplement       0.979667
# 16                 housing  TVComplement       0.957400
# 17                     job  TVComplement       0.946133
# 18           own_telephone  TVComplement       0.869733
# 19          foreign_worker  TVComplement       0.995700
# 20                   class  TVComplement       0.888867
# ------------- Combined Quality score------------
#                     Column        Metric  Quality Score_1  Quality Score_2
# 0                 duration  KSComplement         0.900233         0.866600
# 1            credit_amount  KSComplement         0.939000         0.592633
# 2   installment_commitment  KSComplement         0.951000         0.896733
# 3          residence_since  KSComplement         0.927133         0.927200
# 4                      age  KSComplement         0.977800         0.870700
# 5         existing_credits  KSComplement         0.883900         0.779533
# 6           num_dependents  KSComplement         0.934433         0.879267
# 7          checking_status  TVComplement         0.859067         0.874200
# 8           credit_history  TVComplement         0.812833         0.946100
# 9                  purpose  TVComplement         0.803333         0.902133
# 10          savings_status  TVComplement         0.646467         0.968933
# 11              employment  TVComplement         0.823167         0.936400
# 12         personal_status  TVComplement         0.914600         0.937733
# 13           other_parties  TVComplement         0.883467         0.939400
# 14      property_magnitude  TVComplement         0.941000         0.919867
# 15     other_payment_plans  TVComplement         0.919667         0.979667
# 16                 housing  TVComplement         0.863600         0.957400
# 17                     job  TVComplement         0.905000         0.946133
# 18           own_telephone  TVComplement         0.963500         0.869733
# 19          foreign_worker  TVComplement         0.911667         0.995700
# 20                   class  TVComplement         0.936167         0.888867
# Name of columns for which transformation have  been used:
# ['duration', 'credit_amount', 'installment_commitment', 'property_magnitude', 'age', 'existing_credits', 'num_dependents', 'own_telephone', 'class']
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": None,
#         "duration": None,
#         "credit_history": None,
#         "purpose": None,
#         "credit_amount": None,
#         "savings_status": None,
#         "employment": None,
#         "installment_commitment": None,
#         "personal_status": None,
#         "other_parties": None,
#         "residence_since": None,
#         "property_magnitude": LabelEncoder(),
#         "age": None,
#         "other_payment_plans": None,
#         "housing": None,
#         "existing_credits": None,
#         "job": None,
#         "num_dependents": None,
#         "own_telephone": LabelEncoder(),
#         "foreign_worker": None,
#         "class": LabelEncoder()
#     }
# }
# Details of transformation22
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": None,
#         "duration": None,
#         "credit_history": None,
#         "purpose": None,
#         "credit_amount": None,
#         "savings_status": None,
#         "employment": None,
#         "installment_commitment": None,
#         "personal_status": None,
#         "other_parties": None,
#         "residence_since": None,
#         "property_magnitude": LabelEncoder(),
#         "age": None,
#         "other_payment_plans": None,
#         "housing": None,
#         "existing_credits": None,
#         "job": None,
#         "num_dependents": None,
#         "own_telephone": LabelEncoder(),
#         "foreign_worker": None,
#         "class": LabelEncoder()
#     }
# }
# Hybrid quality score
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.32it/s]
# Overall Quality Score: 91.59%
#
# Properties:
# Column Shapes: 93.99%
# Column Pair Trends: 89.18%
# Hybrid dataset report:
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.900233
# 1            credit_amount  KSComplement       0.939000
# 2   installment_commitment  KSComplement       0.951000
# 3          residence_since  KSComplement       0.927200
# 4                      age  KSComplement       0.977800
# 5         existing_credits  KSComplement       0.883900
# 6           num_dependents  KSComplement       0.934433
# 7          checking_status  TVComplement       0.874200
# 8           credit_history  TVComplement       0.946100
# 9                  purpose  TVComplement       0.902133
# 10          savings_status  TVComplement       0.968933
# 11              employment  TVComplement       0.936400
# 12         personal_status  TVComplement       0.937733
# 13           other_parties  TVComplement       0.939400
# 14      property_magnitude  TVComplement       0.941000
# 15     other_payment_plans  TVComplement       0.979667
# 16                 housing  TVComplement       0.957400
# 17                     job  TVComplement       0.946133
# 18           own_telephone  TVComplement       0.963500
# 19          foreign_worker  TVComplement       0.995700
# 20                   class  TVComplement       0.936167
#  Combined Quality score
#                     Column        Metric  Quality Score_1  Quality Score_2  \
# 0                 duration  KSComplement         0.900233         0.866600
# 1            credit_amount  KSComplement         0.939000         0.592633
# 2   installment_commitment  KSComplement         0.951000         0.896733
# 3          residence_since  KSComplement         0.927133         0.927200
# 4                      age  KSComplement         0.977800         0.870700
# 5         existing_credits  KSComplement         0.883900         0.779533
# 6           num_dependents  KSComplement         0.934433         0.879267
# 7          checking_status  TVComplement         0.859067         0.874200
# 8           credit_history  TVComplement         0.812833         0.946100
# 9                  purpose  TVComplement         0.803333         0.902133
# 10          savings_status  TVComplement         0.646467         0.968933
# 11              employment  TVComplement         0.823167         0.936400
# 12         personal_status  TVComplement         0.914600         0.937733
# 13           other_parties  TVComplement         0.883467         0.939400
# 14      property_magnitude  TVComplement         0.941000         0.919867
# 15     other_payment_plans  TVComplement         0.919667         0.979667
# 16                 housing  TVComplement         0.863600         0.957400
# 17                     job  TVComplement         0.905000         0.946133
# 18           own_telephone  TVComplement         0.963500         0.869733
# 19          foreign_worker  TVComplement         0.911667         0.995700
# 20                   class  TVComplement         0.936167         0.888867
#
#     Quality Score_3
# 0          0.900233
# 1          0.939000
# 2          0.951000
# 3          0.927200
# 4          0.977800
# 5          0.883900
# 6          0.934433
# 7          0.874200
# 8          0.946100
# 9          0.902133
# 10         0.968933
# 11         0.936400
# 12         0.937733
# 13         0.939400
# 14         0.941000
# 15         0.979667
# 16         0.957400
# 17         0.946133
# 18         0.963500
# 19         0.995700
# 20         0.936167

# %%
hybrid(real_data,new_data2,synthetic_dataCTGAN2,metadata)
# Out:
# First dataset quality score:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.10it/s]
# Overall Quality Score: 85.47%
#
# Properties:
# Column Shapes: 89.03%
# Column Pair Trends: 81.9%
# Second dataset quality score:
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.00it/s]
# Overall Quality Score: 81.8%
#
# Properties:
# Column Shapes: 84.55%
# Column Pair Trends: 79.06%
# --------------First dataset report:-------------
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.900233
# 1            credit_amount  KSComplement       0.939000
# 2   installment_commitment  KSComplement       0.951000
# 3          residence_since  KSComplement       0.927133
# 4                      age  KSComplement       0.977800
# 5         existing_credits  KSComplement       0.883900
# 6           num_dependents  KSComplement       0.934433
# 7          checking_status  TVComplement       0.859067
# 8           credit_history  TVComplement       0.812833
# 9                  purpose  TVComplement       0.803333
# 10          savings_status  TVComplement       0.646467
# 11              employment  TVComplement       0.823167
# 12         personal_status  TVComplement       0.914600
# 13           other_parties  TVComplement       0.883467
# 14      property_magnitude  TVComplement       0.941000
# 15     other_payment_plans  TVComplement       0.919667
# 16                 housing  TVComplement       0.863600
# 17                     job  TVComplement       0.905000
# 18           own_telephone  TVComplement       0.963500
# 19          foreign_worker  TVComplement       0.911667
# 20                   class  TVComplement       0.936167
# --------------Second dataset report:------------
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.758667
# 1            credit_amount  KSComplement       0.473667
# 2   installment_commitment  KSComplement       0.880767
# 3          residence_since  KSComplement       0.946767
# 4                      age  KSComplement       0.623600
# 5         existing_credits  KSComplement       0.829533
# 6           num_dependents  KSComplement       0.930967
# 7          checking_status  TVComplement       0.819433
# 8           credit_history  TVComplement       0.861900
# 9                  purpose  TVComplement       0.870800
# 10          savings_status  TVComplement       0.887967
# 11              employment  TVComplement       0.885000
# 12         personal_status  TVComplement       0.781800
# 13           other_parties  TVComplement       0.941833
# 14      property_magnitude  TVComplement       0.896200
# 15     other_payment_plans  TVComplement       0.949367
# 16                 housing  TVComplement       0.766033
# 17                     job  TVComplement       0.822500
# 18           own_telephone  TVComplement       0.868967
# 19          foreign_worker  TVComplement       0.963500
# 20                   class  TVComplement       0.995333
# ------------- Combined Quality score------------
#                     Column        Metric  Quality Score_1  Quality Score_2
# 0                 duration  KSComplement         0.900233         0.758667
# 1            credit_amount  KSComplement         0.939000         0.473667
# 2   installment_commitment  KSComplement         0.951000         0.880767
# 3          residence_since  KSComplement         0.927133         0.946767
# 4                      age  KSComplement         0.977800         0.623600
# 5         existing_credits  KSComplement         0.883900         0.829533
# 6           num_dependents  KSComplement         0.934433         0.930967
# 7          checking_status  TVComplement         0.859067         0.819433
# 8           credit_history  TVComplement         0.812833         0.861900
# 9                  purpose  TVComplement         0.803333         0.870800
# 10          savings_status  TVComplement         0.646467         0.887967
# 11              employment  TVComplement         0.823167         0.885000
# 12         personal_status  TVComplement         0.914600         0.781800
# 13           other_parties  TVComplement         0.883467         0.941833
# 14      property_magnitude  TVComplement         0.941000         0.896200
# 15     other_payment_plans  TVComplement         0.919667         0.949367
# 16                 housing  TVComplement         0.863600         0.766033
# 17                     job  TVComplement         0.905000         0.822500
# 18           own_telephone  TVComplement         0.963500         0.868967
# 19          foreign_worker  TVComplement         0.911667         0.963500
# 20                   class  TVComplement         0.936167         0.995333
# Name of columns for which transformation have  been used:
# ['checking_status', 'duration', 'credit_amount', 'installment_commitment', 'personal_status', 'property_magnitude', 'age', 'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone']
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": LabelEncoder(),
#         "duration": None,
#         "credit_history": None,
#         "purpose": None,
#         "credit_amount": None,
#         "savings_status": None,
#         "employment": None,
#         "installment_commitment": None,
#         "personal_status": LabelEncoder(),
#         "other_parties": None,
#         "residence_since": None,
#         "property_magnitude": LabelEncoder(),
#         "age": None,
#         "other_payment_plans": None,
#         "housing": LabelEncoder(),
#         "existing_credits": None,
#         "job": LabelEncoder(),
#         "num_dependents": None,
#         "own_telephone": LabelEncoder(),
#         "foreign_worker": None,
#         "class": None
#     }
# }
# Details of transformation22
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": LabelEncoder(),
#         "duration": None,
#         "credit_history": None,
#         "purpose": None,
#         "credit_amount": None,
#         "savings_status": None,
#         "employment": None,
#         "installment_commitment": None,
#         "personal_status": LabelEncoder(),
#         "other_parties": None,
#         "residence_since": None,
#         "property_magnitude": LabelEncoder(),
#         "age": None,
#         "other_payment_plans": None,
#         "housing": LabelEncoder(),
#         "existing_credits": None,
#         "job": LabelEncoder(),
#         "num_dependents": None,
#         "own_telephone": LabelEncoder(),
#         "foreign_worker": None,
#         "class": None
#     }
# }
# Hybrid quality score
# Creating report: 100%|███████████████████████████████████████████████████████████████████| 4/4 [00:04<00:00,  1.16s/it]
# Overall Quality Score: 89.29%
#
# Properties:
# Column Shapes: 92.07%
# Column Pair Trends: 86.5%
# Hybrid dataset report:
#                     Column        Metric  Quality Score
# 0                 duration  KSComplement       0.900233
# 1            credit_amount  KSComplement       0.939000
# 2   installment_commitment  KSComplement       0.951000
# 3          residence_since  KSComplement       0.946767
# 4                      age  KSComplement       0.977800
# 5         existing_credits  KSComplement       0.883900
# 6           num_dependents  KSComplement       0.934433
# 7          checking_status  TVComplement       0.859067
# 8           credit_history  TVComplement       0.861900
# 9                  purpose  TVComplement       0.870800
# 10          savings_status  TVComplement       0.887967
# 11              employment  TVComplement       0.885000
# 12         personal_status  TVComplement       0.914600
# 13           other_parties  TVComplement       0.941833
# 14      property_magnitude  TVComplement       0.941000
# 15     other_payment_plans  TVComplement       0.949367
# 16                 housing  TVComplement       0.863600
# 17                     job  TVComplement       0.905000
# 18           own_telephone  TVComplement       0.963500
# 19          foreign_worker  TVComplement       0.963500
# 20                   class  TVComplement       0.995333
#  Combined Quality score
#                     Column        Metric  Quality Score_1  Quality Score_2  \
# 0                 duration  KSComplement         0.900233         0.758667
# 1            credit_amount  KSComplement         0.939000         0.473667
# 2   installment_commitment  KSComplement         0.951000         0.880767
# 3          residence_since  KSComplement         0.927133         0.946767
# 4                      age  KSComplement         0.977800         0.623600
# 5         existing_credits  KSComplement         0.883900         0.829533
# 6           num_dependents  KSComplement         0.934433         0.930967
# 7          checking_status  TVComplement         0.859067         0.819433
# 8           credit_history  TVComplement         0.812833         0.861900
# 9                  purpose  TVComplement         0.803333         0.870800
# 10          savings_status  TVComplement         0.646467         0.887967
# 11              employment  TVComplement         0.823167         0.885000
# 12         personal_status  TVComplement         0.914600         0.781800
# 13           other_parties  TVComplement         0.883467         0.941833
# 14      property_magnitude  TVComplement         0.941000         0.896200
# 15     other_payment_plans  TVComplement         0.919667         0.949367
# 16                 housing  TVComplement         0.863600         0.766033
# 17                     job  TVComplement         0.905000         0.822500
# 18           own_telephone  TVComplement         0.963500         0.868967
# 19          foreign_worker  TVComplement         0.911667         0.963500
# 20                   class  TVComplement         0.936167         0.995333
#
#     Quality Score_3
# 0          0.900233
# 1          0.939000
# 2          0.951000
# 3          0.946767
# 4          0.977800
# 5          0.883900
# 6          0.934433
# 7          0.859067
# 8          0.861900
# 9          0.870800
# 10         0.887967
# 11         0.885000
# 12         0.914600
# 13         0.941833
# 14         0.941000
# 15         0.949367
# 16         0.863600
# 17         0.905000
# 18         0.963500
# 19         0.963500
# 20         0.995333

# %%
#removing columns:
ht = HyperTransformer()
ht.detect_initial_config(data=real_data)
col = real_data.columns
col =[i for i in col if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] < tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]]  
print(col)
# do not transform the credit_card or age columns
ht.remove_transformers(column_names=col)
# do not transform any categorical columns in the dataset
ht.remove_transformers_by_sdtype(sdtype='numerical')
config = ht.get_config()
config

# %%
print(col)

# %%
tab1

# %%
from rdt.transformers.categorical import LabelEncoder
ht.update_transformers(column_name_to_transformer={
        "checking_status": LabelEncoder(),
        "duration": None,
        "credit_history":LabelEncoder(),
        "purpose": None,
        "credit_amount": None,
        "savings_status": LabelEncoder(),
        "employment": LabelEncoder(),
        "installment_commitment": None,
        "personal_status": LabelEncoder(),
        "other_parties": LabelEncoder(),
        "residence_since": None,
        "property_magnitude": LabelEncoder(),
        "age": None,
        "other_payment_plans": None,
        "housing": None,
        "existing_credits": None,
        "job": LabelEncoder(),
        "num_dependents": None,
        "own_telephone": LabelEncoder(),
        "foreign_worker": LabelEncoder(),
        "class": None
    })

# %%
    col1 =[i for i in col if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] < tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]]  
    # do not transform the credit_card or age columns
    ht.remove_transformers(column_names=col1)
    # do not transform any categorical columns in the dataset
    ht.remove_transformers_by_sdtype(sdtype='numerical')
    config = ht.get_config()
    print("Details of transformation")
    print(config)
    print("Name of columns for which transformation have  been used:")
    col=[i for i in col if i not in col1]
    print(col)

# %%
    #merging datasets
    df2=gan_data
    df1=new_data
    ht.fit(df2)
    transformed_df2 = ht.transform(df2)
    ht.fit(df1)
    transformed_df1 = ht.transform(df1)
    col=df1.columns
    dff2=transformed_df2
    dff1=transformed_df1
    for i in col:
        if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] > tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]:
            dff2=dff2.sort_values(by=[i])
            dff1=dff1.sort_values(by=[i])
            dff2[i]=dff1[i]
    #reversing conversion
    
    reversed_dff = ht.reverse_transform(dff2)
    
    
    print("Hybrid quality score")
    quality_report4 = evaluate_quality(
    real_data,
    reversed_dff,
    metadata) 
    
    #qualityscore
    tab3=quality_report4.get_details('Column Shapes')
    print("Hybrid dataset report:")
    print(tab3)
    print(" Combined Quality score")
    tab1['Quality Score_3']=tab3['Quality Score']

# %%
tab1

# %%
from rdt import HyperTransformer
from rdt.transformers.categorical import LabelEncoder
from sklearn import preprocessing
def hybrid(real_data,df1,df2,metadata,col):
    print("First dataset quality score:")
    quality_report1 = evaluate_quality(
    real_data,
    df1,
    metadata)
    print("Second dataset quality score:")
    quality_report2 = evaluate_quality(
    real_data,
    df2,
    metadata)
    tab1=quality_report1.get_details('Column Shapes')
    tab2=quality_report2.get_details('Column Shapes')
    print("--------------First dataset report:-------------")
    print(tab1)
    print("--------------Second dataset report:------------")
    print(tab2)
    print("------------- Combined Quality score------------")
    tab1['Quality Score_1']=tab1['Quality Score']
    tab1['Quality Score_2']=tab2['Quality Score']
    tab1=tab1.drop('Quality Score',axis=1)
    print(tab1)
    #conversion of data
    
    le = preprocessing.LabelEncoder()
    
    #Transformaer update(only for those variable that are not of good quality)
    
    col1 =[i for i in col if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] < tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]]  
    # do not transform the credit_card or age columns
    ht.remove_transformers(column_names=col1)
    # do not transform any categorical columns in the dataset
    ht.remove_transformers_by_sdtype(sdtype='numerical')
    config = ht.get_config()
    print("Details of transformation")
    print(config)
    print("Name of columns for which transformation have  been used:")
    col=[i for i in col if i not in col1]
    print(col)
    
    
    #merging datasets 
    
    dff2=transformed_df2
    dff1=transformed_df1
    for i in col:
        if tab1.loc[tab1['Column']==i, 'Quality Score_1'].values[0] > tab1.loc[tab1['Column']==i, 'Quality Score_2'].values[0]:
            dff2=dff2.sort_values(by=[i])
            dff1=dff1.sort_values(by=[i])
            dff2[i]=dff1[i]
    #reversing conversion
    
    reversed_dff = ht.reverse_transform(dff2)
    
    
    print("Hybrid quality score")
    quality_report4 = evaluate_quality(
    real_data,
    reversed_dff,
    metadata) 
    
    #qualityscore
    tab3=quality_report4.get_details('Column Shapes')
    print("Hybrid dataset report:")
    print(tab3)
    print(" Combined Quality score")
    tab1['Quality Score_3']=tab3['Quality Score']
    
    
    return tab1

# %%
from rdt import HyperTransformer
ht = HyperTransformer()
ht.detect_initial_config(data=real_data)
col = real_data.columns
col
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
config = ht.get_config()
config
# Out:
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": FrequencyEncoder(),
#         "duration": FloatFormatter(),
#         "credit_history": FrequencyEncoder(),
#         "purpose": FrequencyEncoder(),
#         "credit_amount": FloatFormatter(),
#         "savings_status": FrequencyEncoder(),
#         "employment": FrequencyEncoder(),
#         "installment_commitment": FloatFormatter(),
#         "personal_status": FrequencyEncoder(),
#         "other_parties": FrequencyEncoder(),
#         "residence_since": FloatFormatter(),
#         "property_magnitude": FrequencyEncoder(),
#         "age": FloatFormatter(),
#         "other_payment_plans": FrequencyEncoder(),
#         "housing": FrequencyEncoder(),
#         "existing_credits": FloatFormatter(),
#         "job": FrequencyEncoder(),
#         "num_dependents": FloatFormatter(),
#         "own_telephone": FrequencyEncoder(),
#         "foreign_worker": FrequencyEncoder(),
#         "class": FrequencyEncoder()
#     }
# }

# %%
from rdt.transformers.categorical import LabelEncoder

for feature in col:
    if config["transformers"][feature] == 'FrequencyEncoder()' :
        config["transformers"][feature] = LabelEncoder()

# %%
config
# Out:
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": FrequencyEncoder(),
#         "duration": FloatFormatter(),
#         "credit_history": FrequencyEncoder(),
#         "purpose": FrequencyEncoder(),
#         "credit_amount": FloatFormatter(),
#         "savings_status": FrequencyEncoder(),
#         "employment": FrequencyEncoder(),
#         "installment_commitment": FloatFormatter(),
#         "personal_status": FrequencyEncoder(),
#         "other_parties": FrequencyEncoder(),
#         "residence_since": FloatFormatter(),
#         "property_magnitude": FrequencyEncoder(),
#         "age": FloatFormatter(),
#         "other_payment_plans": FrequencyEncoder(),
#         "housing": FrequencyEncoder(),
#         "existing_credits": FloatFormatter(),
#         "job": FrequencyEncoder(),
#         "num_dependents": FloatFormatter(),
#         "own_telephone": FrequencyEncoder(),
#         "foreign_worker": FrequencyEncoder(),
#         "class": FrequencyEncoder()
#     }
# }

# %%
for feature in col:
    if config["transformers"][feature] == 'FrequencyEncoder()' :
          print(feature)

# %%
for feature in col:
    if config["transformers"][feature].__class__.__name__ == 'FrequencyEncoder':
        config["transformers"][feature] = LabelEncoder()

config
# Out:
# {
#     "sdtypes": {
#         "checking_status": "categorical",
#         "duration": "numerical",
#         "credit_history": "categorical",
#         "purpose": "categorical",
#         "credit_amount": "numerical",
#         "savings_status": "categorical",
#         "employment": "categorical",
#         "installment_commitment": "numerical",
#         "personal_status": "categorical",
#         "other_parties": "categorical",
#         "residence_since": "numerical",
#         "property_magnitude": "categorical",
#         "age": "numerical",
#         "other_payment_plans": "categorical",
#         "housing": "categorical",
#         "existing_credits": "numerical",
#         "job": "categorical",
#         "num_dependents": "numerical",
#         "own_telephone": "categorical",
#         "foreign_worker": "categorical",
#         "class": "categorical"
#     },
#     "transformers": {
#         "checking_status": LabelEncoder(),
#         "duration": FloatFormatter(),
#         "credit_history": LabelEncoder(),
#         "purpose": LabelEncoder(),
#         "credit_amount": FloatFormatter(),
#         "savings_status": LabelEncoder(),
#         "employment": LabelEncoder(),
#         "installment_commitment": FloatFormatter(),
#         "personal_status": LabelEncoder(),
#         "other_parties": LabelEncoder(),
#         "residence_since": FloatFormatter(),
#         "property_magnitude": LabelEncoder(),
#         "age": FloatFormatter(),
#         "other_payment_plans": LabelEncoder(),
#         "housing": LabelEncoder(),
#         "existing_credits": FloatFormatter(),
#         "job": LabelEncoder(),
#         "num_dependents": FloatFormatter(),
#         "own_telephone": LabelEncoder(),
#         "foreign_worker": LabelEncoder(),
#         "class": LabelEncoder()
#     }
# }
